# %% [markdown]
# table from page 1 area = ['0,620,600,475']
#
# table from page 2 area = ['0,915,600,0']

# %%
import camelot as cm

# %%
pdf8 = cm.read_pdf('./pdf/Credit Card Statement 21-08.pdf',password='VIVE0791',flavor='stream',table_areas=['0,915,600,0'],pages='2')

# %%
pdf8
# Out:
# <TableList n=1>

# %%
cm.plot(pdf8[0],kind='text').show()

# %%
pdf8[0].df
# Out:
#                 0                                                  1  \
# 0      19/07/2021                          HOTEL GURUKRUPABELGAUMIND
# 1      19/07/2021                          IMPS PAYMENT#119915919431
# 2      20/07/2021                   MKSWAMY  SONS THE ORIGBELGAUMIND
# 3      20/07/2021                     RELIANCE FRESHBELGAUM\56000IND
# 4      23/07/2021                          IMPS PAYMENT#120412013420
# 5      24/07/2021                                 MI STOREBELGAUMIND
# 6      24/07/2021                     RELIANCE FRESHBELGAUM\56000IND
# 7      26/07/2021                          IMPS PAYMENT#120513042264
# 8      26/07/2021                          IMPS PAYMENT#120513727991
# 9      27/07/2021                                                GST
# 10     27/07/2021  TRANSACTION CONVERSION INTO EMI         MOBI L...
# 11     27/07/2021  EMI PROCESSING FEE, REF# 20216629            M...
# 12     27/07/2021                          IMPS PAYMENT#120815671675
# ...
